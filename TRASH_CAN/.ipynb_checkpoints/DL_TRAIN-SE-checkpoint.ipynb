# %%
from py_env_train import *

# Define the following for network configs:
loss = "mse"
#min_LR = 0.0001
lr_patience = 2
patience = 8
epochs = 64
val_split = 0.5
n_channels = 7
xpixels = 128
ypixels = 256

n_samples = 10
x = 128
y = 256
n_channels = 7
LR=0.1
BS=2
lr_factor=0.5
Filters=16
min_LR=None

# %% [markdown]
# Experiment 1) Let's start the experiment: we have train_x and train_y, which are exactly the same as val_x and val_y.

# %%
import random
random.seed(1)
random_data = np.random.rand(n_samples, x, y, n_channels - 2)

channel1_data = np.ones((n_samples, x, y))
channel2_data = np.ones((n_samples, x, y)) * 2

train_x = np.concatenate((channel1_data[:, :, :, np.newaxis],
                          channel2_data[:, :, :, np.newaxis],
                          random_data), axis=-1)

train_y = np.full((n_samples, x, y, 1), 10, dtype=np.float32)

val_x = train_x*1
val_y = train_y*1

train_m = np.ones((n_samples, x, y, 1), dtype=np.float32)
val_m = np.ones((n_samples, x, y, 1), dtype=np.float32)

training_unique_name="experiment_sample_weight"
model = Func_Train.UNET(xpixels, ypixels, n_channels, Filters)

# Define optimizer and compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=LR, name='Adam')
#model.compile(optimizer=optimizer, loss=loss, weighted_metrics=['mse'], sample_weight_mode='temporal')
model.compile(optimizer=optimizer, loss=loss, weighted_metrics=[])

# Define the model checkpoint and early stopping callbacks
model_path = PSCRATCH_DIR + '/HPT/' + training_unique_name + '.h5'
checkpointer = tf.keras.callbacks.ModelCheckpoint(model_path, verbose=2, save_best_only=True, monitor='val_loss')
callbacks = [tf.keras.callbacks.EarlyStopping(patience=patience, monitor='val_loss'),
             tf.keras.callbacks.TensorBoard(log_dir=PSCRATCH_DIR + '/HPT/' + training_unique_name)]

# Define the ReduceLROnPlateau callback
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=lr_factor, patience=lr_patience, min_lr=min_LR)

print("Training the model...")

# Train the model using train_x, train_y, train_m and val_x, val_y, val_m
results = model.fit(train_x, train_y, validation_data=(val_x, val_y, val_m),
                    batch_size=BS, epochs=epochs, verbose=2,
                    callbacks=[callbacks, checkpointer, reduce_lr], sample_weight=train_m,
                    shuffle=False)
# Out:
# Training the model...
# Epoch 1/64
#
# Epoch 1: val_loss improved from inf to 3524599421801070592.00000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 8s - loss: 81.4837 - val_loss: 3524599421801070592.0000 - lr: 0.1000 - 8s/epoch - 2s/step
# Epoch 2/64
#
# Epoch 2: val_loss improved from 3524599421801070592.00000 to 3300407902208.00000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 13.9630 - val_loss: 3300407902208.0000 - lr: 0.1000 - 1s/epoch - 246ms/step
# Epoch 3/64
#
# Epoch 3: val_loss improved from 3300407902208.00000 to 637459968.00000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 14.8164 - val_loss: 637459968.0000 - lr: 0.1000 - 1s/epoch - 295ms/step
# Epoch 4/64
#
# Epoch 4: val_loss improved from 637459968.00000 to 414714.87500, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.7800 - val_loss: 414714.8750 - lr: 0.1000 - 1s/epoch - 249ms/step
# Epoch 5/64
#
# Epoch 5: val_loss improved from 414714.87500 to 26313.25391, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.7060 - val_loss: 26313.2539 - lr: 0.1000 - 1s/epoch - 256ms/step
# Epoch 6/64
#
# Epoch 6: val_loss improved from 26313.25391 to 3376.36377, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.9233 - val_loss: 3376.3638 - lr: 0.1000 - 1s/epoch - 251ms/step
# Epoch 7/64
#
# Epoch 7: val_loss improved from 3376.36377 to 1338.31189, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.7937 - val_loss: 1338.3119 - lr: 0.1000 - 1s/epoch - 241ms/step
# Epoch 8/64
#
# Epoch 8: val_loss improved from 1338.31189 to 545.81329, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.3195 - val_loss: 545.8133 - lr: 0.1000 - 1s/epoch - 256ms/step
# Epoch 9/64
#
# Epoch 9: val_loss improved from 545.81329 to 336.28232, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.6935 - val_loss: 336.2823 - lr: 0.1000 - 1s/epoch - 263ms/step
# Epoch 10/64
#
# Epoch 10: val_loss improved from 336.28232 to 275.12726, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.1228 - val_loss: 275.1273 - lr: 0.1000 - 1s/epoch - 243ms/step
# Epoch 11/64
#
# Epoch 11: val_loss improved from 275.12726 to 151.10429, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.2522 - val_loss: 151.1043 - lr: 0.1000 - 1s/epoch - 243ms/step
# Epoch 12/64
#
# Epoch 12: val_loss improved from 151.10429 to 85.48918, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0403 - val_loss: 85.4892 - lr: 0.1000 - 1s/epoch - 250ms/step
# Epoch 13/64
#
# Epoch 13: val_loss improved from 85.48918 to 57.62843, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0908 - val_loss: 57.6284 - lr: 0.1000 - 1s/epoch - 239ms/step
# Epoch 14/64
#
# Epoch 14: val_loss improved from 57.62843 to 50.34057, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0215 - val_loss: 50.3406 - lr: 0.1000 - 1s/epoch - 271ms/step
# Epoch 15/64
#
# Epoch 15: val_loss improved from 50.34057 to 35.22063, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 2s - loss: 0.0245 - val_loss: 35.2206 - lr: 0.1000 - 2s/epoch - 386ms/step
# Epoch 16/64
#
# Epoch 16: val_loss improved from 35.22063 to 23.41345, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0149 - val_loss: 23.4135 - lr: 0.1000 - 1s/epoch - 235ms/step
# Epoch 17/64
#
# Epoch 17: val_loss improved from 23.41345 to 19.98782, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0047 - val_loss: 19.9878 - lr: 0.1000 - 1s/epoch - 244ms/step
# Epoch 18/64
#
# Epoch 18: val_loss improved from 19.98782 to 15.76669, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0071 - val_loss: 15.7667 - lr: 0.1000 - 1s/epoch - 248ms/step
# Epoch 19/64
#
# Epoch 19: val_loss improved from 15.76669 to 11.90532, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0019 - val_loss: 11.9053 - lr: 0.1000 - 1s/epoch - 244ms/step
# Epoch 20/64
#
# Epoch 20: val_loss improved from 11.90532 to 10.12380, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0018 - val_loss: 10.1238 - lr: 0.1000 - 1s/epoch - 273ms/step
# Epoch 21/64
#
# Epoch 21: val_loss improved from 10.12380 to 8.09836, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0015 - val_loss: 8.0984 - lr: 0.1000 - 1s/epoch - 247ms/step
# Epoch 22/64
#
# Epoch 22: val_loss improved from 8.09836 to 7.13030, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.3905e-04 - val_loss: 7.1303 - lr: 0.1000 - 1s/epoch - 247ms/step
# Epoch 23/64
#
# Epoch 23: val_loss improved from 7.13030 to 5.97391, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.3381e-04 - val_loss: 5.9739 - lr: 0.1000 - 1s/epoch - 279ms/step
# Epoch 24/64
#
# Epoch 24: val_loss improved from 5.97391 to 5.23686, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 3.6466e-04 - val_loss: 5.2369 - lr: 0.1000 - 1s/epoch - 252ms/step
# Epoch 25/64
#
# Epoch 25: val_loss improved from 5.23686 to 4.41816, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.7265e-04 - val_loss: 4.4182 - lr: 0.1000 - 1s/epoch - 290ms/step
# Epoch 26/64
#
# Epoch 26: val_loss improved from 4.41816 to 3.83030, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.8476e-04 - val_loss: 3.8303 - lr: 0.1000 - 1s/epoch - 257ms/step
# Epoch 27/64
#
# Epoch 27: val_loss improved from 3.83030 to 3.25904, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.4908e-04 - val_loss: 3.2590 - lr: 0.1000 - 1s/epoch - 294ms/step
# Epoch 28/64
#
# Epoch 28: val_loss improved from 3.25904 to 2.82853, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.0514e-04 - val_loss: 2.8285 - lr: 0.1000 - 1s/epoch - 243ms/step
# Epoch 29/64
#
# Epoch 29: val_loss improved from 2.82853 to 2.47329, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.0103e-04 - val_loss: 2.4733 - lr: 0.1000 - 1s/epoch - 244ms/step
# Epoch 30/64
#
# Epoch 30: val_loss improved from 2.47329 to 2.15513, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 9.4897e-05 - val_loss: 2.1551 - lr: 0.1000 - 1s/epoch - 277ms/step
# Epoch 31/64
#
# Epoch 31: val_loss improved from 2.15513 to 1.89515, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 8.3506e-05 - val_loss: 1.8952 - lr: 0.1000 - 1s/epoch - 254ms/step
# Epoch 32/64
#
# Epoch 32: val_loss improved from 1.89515 to 1.67142, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 7.8656e-05 - val_loss: 1.6714 - lr: 0.1000 - 1s/epoch - 259ms/step
# Epoch 33/64
#
# Epoch 33: val_loss improved from 1.67142 to 1.48068, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 7.6236e-05 - val_loss: 1.4807 - lr: 0.1000 - 1s/epoch - 247ms/step
# Epoch 34/64
#
# Epoch 34: val_loss improved from 1.48068 to 1.31600, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 7.2669e-05 - val_loss: 1.3160 - lr: 0.1000 - 1s/epoch - 259ms/step
# Epoch 35/64
#
# Epoch 35: val_loss improved from 1.31600 to 1.17337, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 2s - loss: 6.9512e-05 - val_loss: 1.1734 - lr: 0.1000 - 2s/epoch - 304ms/step
# Epoch 36/64
#
# Epoch 36: val_loss improved from 1.17337 to 1.05116, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 6.7320e-05 - val_loss: 1.0512 - lr: 0.1000 - 1s/epoch - 246ms/step
# Epoch 37/64
#
# Epoch 37: val_loss improved from 1.05116 to 0.94192, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 6.5378e-05 - val_loss: 0.9419 - lr: 0.1000 - 1s/epoch - 248ms/step
# Epoch 38/64
#
# Epoch 38: val_loss improved from 0.94192 to 0.84600, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 6.3500e-05 - val_loss: 0.8460 - lr: 0.1000 - 1s/epoch - 257ms/step
# Epoch 39/64
#
# Epoch 39: val_loss improved from 0.84600 to 0.76229, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 6.1879e-05 - val_loss: 0.7623 - lr: 0.1000 - 1s/epoch - 253ms/step
# Epoch 40/64
#
# Epoch 40: val_loss improved from 0.76229 to 0.68835, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 6.0571e-05 - val_loss: 0.6884 - lr: 0.1000 - 1s/epoch - 279ms/step
# Epoch 41/64
#
# Epoch 41: val_loss improved from 0.68835 to 0.62414, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.9503e-05 - val_loss: 0.6241 - lr: 0.1000 - 1s/epoch - 268ms/step
# Epoch 42/64
#
# Epoch 42: val_loss improved from 0.62414 to 0.56746, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.8632e-05 - val_loss: 0.5675 - lr: 0.1000 - 1s/epoch - 250ms/step
# Epoch 43/64
#
# Epoch 43: val_loss improved from 0.56746 to 0.51457, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.7874e-05 - val_loss: 0.5146 - lr: 0.1000 - 1s/epoch - 251ms/step
# Epoch 44/64
#
# Epoch 44: val_loss improved from 0.51457 to 0.45843, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.7387e-05 - val_loss: 0.4584 - lr: 0.1000 - 1s/epoch - 264ms/step
# Epoch 45/64
#
# Epoch 45: val_loss improved from 0.45843 to 0.39197, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 2s - loss: 5.7749e-05 - val_loss: 0.3920 - lr: 0.1000 - 2s/epoch - 339ms/step
# Epoch 46/64
#
# Epoch 46: val_loss improved from 0.39197 to 0.32124, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.7358e-05 - val_loss: 0.3212 - lr: 0.1000 - 1s/epoch - 242ms/step
# Epoch 47/64
#
# Epoch 47: val_loss improved from 0.32124 to 0.27019, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.2044e-05 - val_loss: 0.2702 - lr: 0.1000 - 1s/epoch - 258ms/step
# Epoch 48/64
#
# Epoch 48: val_loss improved from 0.27019 to 0.25510, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.8849e-05 - val_loss: 0.2551 - lr: 0.1000 - 1s/epoch - 282ms/step
# Epoch 49/64
#
# Epoch 49: val_loss improved from 0.25510 to 0.23246, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.7020e-05 - val_loss: 0.2325 - lr: 0.1000 - 1s/epoch - 260ms/step
# Epoch 50/64
#
# Epoch 50: val_loss improved from 0.23246 to 0.18145, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.9069e-05 - val_loss: 0.1815 - lr: 0.1000 - 1s/epoch - 246ms/step
# Epoch 51/64
#
# Epoch 51: val_loss did not improve from 0.18145
# 5/5 - 1s - loss: 4.9474e-05 - val_loss: 0.1976 - lr: 0.1000 - 990ms/epoch - 198ms/step
# Epoch 52/64
#
# Epoch 52: val_loss improved from 0.18145 to 0.08430, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 9.1905e-05 - val_loss: 0.0843 - lr: 0.1000 - 1s/epoch - 269ms/step
# Epoch 53/64
#
# Epoch 53: val_loss did not improve from 0.08430
# 5/5 - 1s - loss: 7.4378e-04 - val_loss: 0.6673 - lr: 0.1000 - 1s/epoch - 223ms/step
# Epoch 54/64
#
# Epoch 54: val_loss did not improve from 0.08430
# 5/5 - 1s - loss: 0.0072 - val_loss: 0.1122 - lr: 0.1000 - 990ms/epoch - 198ms/step
# Epoch 55/64
#
# Epoch 55: val_loss improved from 0.08430 to 0.05083, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0030 - val_loss: 0.0508 - lr: 0.1000 - 1s/epoch - 246ms/step
# Epoch 56/64
#
# Epoch 56: val_loss improved from 0.05083 to 0.03483, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0018 - val_loss: 0.0348 - lr: 0.1000 - 1s/epoch - 261ms/step
# Epoch 57/64
#
# Epoch 57: val_loss did not improve from 0.03483
# 5/5 - 1s - loss: 0.0010 - val_loss: 0.0992 - lr: 0.1000 - 1s/epoch - 209ms/step
# Epoch 58/64
#
# Epoch 58: val_loss did not improve from 0.03483
# 5/5 - 1s - loss: 5.9056e-04 - val_loss: 0.1685 - lr: 0.1000 - 1s/epoch - 223ms/step
# Epoch 59/64
#
# Epoch 59: val_loss did not improve from 0.03483
# 5/5 - 1s - loss: 4.1326e-04 - val_loss: 0.1853 - lr: 0.1000 - 1s/epoch - 201ms/step
# Epoch 60/64
#
# Epoch 60: val_loss did not improve from 0.03483
# 5/5 - 1s - loss: 3.0741e-04 - val_loss: 0.1581 - lr: 0.1000 - 975ms/epoch - 195ms/step
# Epoch 61/64
#
# Epoch 61: val_loss did not improve from 0.03483
# 5/5 - 1s - loss: 2.2120e-04 - val_loss: 0.1183 - lr: 0.1000 - 1s/epoch - 204ms/step
# Epoch 62/64
#
# Epoch 62: val_loss did not improve from 0.03483
# 5/5 - 1s - loss: 1.5785e-04 - val_loss: 0.0860 - lr: 0.1000 - 1s/epoch - 213ms/step
# Epoch 63/64
#
# Epoch 63: val_loss did not improve from 0.03483
# 5/5 - 1s - loss: 1.1699e-04 - val_loss: 0.0644 - lr: 0.1000 - 1s/epoch - 202ms/step
# Epoch 64/64
#
# Epoch 64: val_loss did not improve from 0.03483
# 5/5 - 1s - loss: 9.1495e-05 - val_loss: 0.0497 - lr: 0.1000 - 1s/epoch - 204ms/step

# %% [markdown]
# Although train_x = val_x and train_y = val_y, the results of loss and val_loss differ! which is surprising. This is because loss is calculated for the same epoch, whereas val_loss is calculated for the whole validation data.
#
# Experiment 2) Now, let's assume one of the data in `train_y` and `val_y` is nan, but we have replaced it with -999. In `train_m`, we have assigned 0 values for this sample to not include it in the training, but we haven't included it in `val_m`.
#
# We expect that the loss values will not be affected, but val_loss values must be affected.

# %%
import random
random.seed(1)
random_data = np.random.rand(n_samples, x, y, n_channels - 2)

channel1_data = np.ones((n_samples, x, y))
channel2_data = np.ones((n_samples, x, y)) * 2

train_x = np.concatenate((channel1_data[:, :, :, np.newaxis],
                          channel2_data[:, :, :, np.newaxis],
                          random_data), axis=-1)

train_y = np.full((n_samples, x, y, 1), 10, dtype=np.float32)
train_y[5, ...] = -999.

val_x = train_x*1
val_y = train_y*1

train_m = np.ones((n_samples, x, y, 1), dtype=np.float32)
train_m[5, ...] = 0
val_m = np.ones((n_samples, x, y, 1), dtype=np.float32)


training_unique_name="experiment_sample_weight"
model = Func_Train.UNET(xpixels, ypixels, n_channels, Filters)

# Define optimizer and compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=LR, name='Adam')
#model.compile(optimizer=optimizer, loss=loss, weighted_metrics=['mse'], sample_weight_mode='temporal')
model.compile(optimizer=optimizer, loss=loss, weighted_metrics=[])

# Define the model checkpoint and early stopping callbacks
model_path = PSCRATCH_DIR + '/HPT/' + training_unique_name + '.h5'
checkpointer = tf.keras.callbacks.ModelCheckpoint(model_path, verbose=2, save_best_only=True, monitor='val_loss')
callbacks = [tf.keras.callbacks.EarlyStopping(patience=patience, monitor='val_loss'),
             tf.keras.callbacks.TensorBoard(log_dir=PSCRATCH_DIR + '/HPT/' + training_unique_name)]

# Define the ReduceLROnPlateau callback
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=lr_factor, patience=lr_patience, min_lr=min_LR)

print("Training the model...")

# Train the model using train_x, train_y, train_m and val_x, val_y, val_m
results = model.fit(train_x, train_y, validation_data=(val_x, val_y, val_m),
                    batch_size=BS, epochs=epochs, verbose=2,
                    callbacks=[callbacks, checkpointer, reduce_lr], sample_weight=train_m,
                    shuffle=False)
# Out:
# Training the model...
# Epoch 1/64
#
# Epoch 1: val_loss improved from inf to 7648386492661760.00000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 7s - loss: 73.4162 - val_loss: 7648386492661760.0000 - lr: 0.1000 - 7s/epoch - 1s/step
# Epoch 2/64
#
# Epoch 2: val_loss improved from 7648386492661760.00000 to 251752267776.00000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 14.2294 - val_loss: 251752267776.0000 - lr: 0.1000 - 1s/epoch - 265ms/step
# Epoch 3/64
#
# Epoch 3: val_loss improved from 251752267776.00000 to 31888140288.00000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 11.8853 - val_loss: 31888140288.0000 - lr: 0.1000 - 1s/epoch - 260ms/step
# Epoch 4/64
#
# Epoch 4: val_loss improved from 31888140288.00000 to 134961056.00000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.8716 - val_loss: 134961056.0000 - lr: 0.1000 - 1s/epoch - 257ms/step
# Epoch 5/64
#
# Epoch 5: val_loss improved from 134961056.00000 to 95649648.00000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.7694 - val_loss: 95649648.0000 - lr: 0.1000 - 1s/epoch - 275ms/step
# Epoch 6/64
#
# Epoch 6: val_loss improved from 95649648.00000 to 2936242.25000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.0308 - val_loss: 2936242.2500 - lr: 0.1000 - 1s/epoch - 252ms/step
# Epoch 7/64
#
# Epoch 7: val_loss improved from 2936242.25000 to 2828873.50000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.4298 - val_loss: 2828873.5000 - lr: 0.1000 - 1s/epoch - 259ms/step
# Epoch 8/64
#
# Epoch 8: val_loss improved from 2828873.50000 to 525503.75000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.3654 - val_loss: 525503.7500 - lr: 0.1000 - 1s/epoch - 263ms/step
# Epoch 9/64
#
# Epoch 9: val_loss improved from 525503.75000 to 135781.07812, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.5710 - val_loss: 135781.0781 - lr: 0.1000 - 1s/epoch - 251ms/step
# Epoch 10/64
#
# Epoch 10: val_loss improved from 135781.07812 to 123370.08594, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.1333 - val_loss: 123370.0859 - lr: 0.1000 - 1s/epoch - 257ms/step
# Epoch 11/64
#
# Epoch 11: val_loss improved from 123370.08594 to 95975.51562, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.2082 - val_loss: 95975.5156 - lr: 0.1000 - 1s/epoch - 257ms/step
# Epoch 12/64
#
# Epoch 12: val_loss improved from 95975.51562 to 93742.84375, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0430 - val_loss: 93742.8438 - lr: 0.1000 - 1s/epoch - 269ms/step
# Epoch 13/64
#
# Epoch 13: val_loss did not improve from 93742.84375
# 5/5 - 1s - loss: 0.0773 - val_loss: 102253.1719 - lr: 0.1000 - 1s/epoch - 201ms/step
# Epoch 14/64
#
# Epoch 14: val_loss did not improve from 93742.84375
# 5/5 - 1s - loss: 0.0208 - val_loss: 104222.3516 - lr: 0.1000 - 994ms/epoch - 199ms/step
# Epoch 15/64
#
# Epoch 15: val_loss did not improve from 93742.84375
# 5/5 - 1s - loss: 0.0218 - val_loss: 99192.4844 - lr: 0.1000 - 973ms/epoch - 195ms/step
# Epoch 16/64
#
# Epoch 16: val_loss did not improve from 93742.84375
# 5/5 - 1s - loss: 0.0131 - val_loss: 99430.0391 - lr: 0.1000 - 1s/epoch - 203ms/step
# Epoch 17/64
#
# Epoch 17: val_loss did not improve from 93742.84375
# 5/5 - 1s - loss: 0.0049 - val_loss: 101748.5859 - lr: 0.1000 - 1s/epoch - 201ms/step
# Epoch 18/64
#
# Epoch 18: val_loss did not improve from 93742.84375
# 5/5 - 1s - loss: 0.0060 - val_loss: 101789.7969 - lr: 0.1000 - 1s/epoch - 205ms/step
# Epoch 19/64
#
# Epoch 19: val_loss did not improve from 93742.84375
# 5/5 - 1s - loss: 0.0021 - val_loss: 101095.2344 - lr: 0.1000 - 987ms/epoch - 197ms/step
# Epoch 20/64
#
# Epoch 20: val_loss did not improve from 93742.84375
# 5/5 - 1s - loss: 0.0017 - val_loss: 101328.2891 - lr: 0.1000 - 1s/epoch - 202ms/step

# %% [markdown]
# The results from Experiment 2 were exactly as expected.
#
# Experiment 3) Now, let's apply the same in `val_m`.

# %%
import random
random.seed(1)
random_data = np.random.rand(n_samples, x, y, n_channels - 2)

channel1_data = np.ones((n_samples, x, y))
channel2_data = np.ones((n_samples, x, y)) * 2

train_x = np.concatenate((channel1_data[:, :, :, np.newaxis],
                          channel2_data[:, :, :, np.newaxis],
                          random_data), axis=-1)

train_y = np.full((n_samples, x, y, 1), 10, dtype=np.float32)
train_y[5, ...] = -999.

val_x = train_x*1
val_y = train_y*1

train_m = np.ones((n_samples, x, y, 1), dtype=np.float32)
train_m[5, ...] = 0
val_m = np.ones((n_samples, x, y, 1), dtype=np.float32)
val_m[5, ...] = 0

training_unique_name="experiment_sample_weight"
model = Func_Train.UNET(xpixels, ypixels, n_channels, Filters)

# Define optimizer and compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=LR, name='Adam')
#model.compile(optimizer=optimizer, loss=loss, weighted_metrics=['mse'], sample_weight_mode='temporal')
model.compile(optimizer=optimizer, loss=loss, weighted_metrics=[])

# Define the model checkpoint and early stopping callbacks
model_path = PSCRATCH_DIR + '/HPT/' + training_unique_name + '.h5'
checkpointer = tf.keras.callbacks.ModelCheckpoint(model_path, verbose=2, save_best_only=True, monitor='val_loss')
callbacks = [tf.keras.callbacks.EarlyStopping(patience=patience, monitor='val_loss'),
             tf.keras.callbacks.TensorBoard(log_dir=PSCRATCH_DIR + '/HPT/' + training_unique_name)]

# Define the ReduceLROnPlateau callback
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=lr_factor, patience=lr_patience, min_lr=min_LR)

print("Training the model...")

# Train the model using train_x, train_y, train_m and val_x, val_y, val_m
results = model.fit(train_x, train_y, validation_data=(val_x, val_y, val_m),
                    batch_size=BS, epochs=epochs, verbose=2,
                    callbacks=[callbacks, checkpointer, reduce_lr], sample_weight=train_m,
                    shuffle=False)
# Out:
# Training the model...
# Epoch 1/64
#
# Epoch 1: val_loss improved from inf to 99659389337600.00000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 7s - loss: 73.2670 - val_loss: 99659389337600.0000 - lr: 0.1000 - 7s/epoch - 1s/step
# Epoch 2/64
#
# Epoch 2: val_loss improved from 99659389337600.00000 to 18863952.00000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 13.9240 - val_loss: 18863952.0000 - lr: 0.1000 - 1s/epoch - 296ms/step
# Epoch 3/64
#
# Epoch 3: val_loss improved from 18863952.00000 to 10351.16406, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 11.8845 - val_loss: 10351.1641 - lr: 0.1000 - 1s/epoch - 259ms/step
# Epoch 4/64
#
# Epoch 4: val_loss did not improve from 10351.16406
# 5/5 - 1s - loss: 1.8368 - val_loss: 18751.5781 - lr: 0.1000 - 1s/epoch - 207ms/step
# Epoch 5/64
#
# Epoch 5: val_loss improved from 10351.16406 to 1883.67700, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.7380 - val_loss: 1883.6770 - lr: 0.1000 - 1s/epoch - 264ms/step
# Epoch 6/64
#
# Epoch 6: val_loss improved from 1883.67700 to 28.35551, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.0142 - val_loss: 28.3555 - lr: 0.1000 - 1s/epoch - 274ms/step
# Epoch 7/64
#
# Epoch 7: val_loss did not improve from 28.35551
# 5/5 - 1s - loss: 1.4223 - val_loss: 631.8694 - lr: 0.1000 - 1s/epoch - 211ms/step
# Epoch 8/64
#
# Epoch 8: val_loss did not improve from 28.35551
# 5/5 - 1s - loss: 0.3588 - val_loss: 1832.7039 - lr: 0.1000 - 1s/epoch - 215ms/step
# Epoch 9/64
#
# Epoch 9: val_loss did not improve from 28.35551
# 5/5 - 1s - loss: 0.5678 - val_loss: 217.7044 - lr: 0.1000 - 1s/epoch - 209ms/step
# Epoch 10/64
#
# Epoch 10: val_loss did not improve from 28.35551
# 5/5 - 1s - loss: 0.1315 - val_loss: 67.7128 - lr: 0.1000 - 1s/epoch - 205ms/step
# Epoch 11/64
#
# Epoch 11: val_loss did not improve from 28.35551
# 5/5 - 1s - loss: 0.2070 - val_loss: 62.2122 - lr: 0.1000 - 1s/epoch - 203ms/step
# Epoch 12/64
#
# Epoch 12: val_loss did not improve from 28.35551
# 5/5 - 1s - loss: 0.0415 - val_loss: 36.1474 - lr: 0.1000 - 1s/epoch - 223ms/step
# Epoch 13/64
#
# Epoch 13: val_loss improved from 28.35551 to 21.70993, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0774 - val_loss: 21.7099 - lr: 0.1000 - 1s/epoch - 247ms/step
# Epoch 14/64
#
# Epoch 14: val_loss improved from 21.70993 to 11.19506, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0199 - val_loss: 11.1951 - lr: 0.1000 - 1s/epoch - 248ms/step
# Epoch 15/64
#
# Epoch 15: val_loss improved from 11.19506 to 6.78407, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0221 - val_loss: 6.7841 - lr: 0.1000 - 1s/epoch - 260ms/step
# Epoch 16/64
#
# Epoch 16: val_loss improved from 6.78407 to 5.11356, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0127 - val_loss: 5.1136 - lr: 0.1000 - 1s/epoch - 256ms/step
# Epoch 17/64
#
# Epoch 17: val_loss improved from 5.11356 to 4.20224, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0049 - val_loss: 4.2022 - lr: 0.1000 - 1s/epoch - 272ms/step
# Epoch 18/64
#
# Epoch 18: val_loss improved from 4.20224 to 3.19598, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0060 - val_loss: 3.1960 - lr: 0.1000 - 1s/epoch - 259ms/step
# Epoch 19/64
#
# Epoch 19: val_loss improved from 3.19598 to 2.28940, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0021 - val_loss: 2.2894 - lr: 0.1000 - 1s/epoch - 253ms/step
# Epoch 20/64
#
# Epoch 20: val_loss improved from 2.28940 to 1.38762, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0018 - val_loss: 1.3876 - lr: 0.1000 - 1s/epoch - 257ms/step
# Epoch 21/64
#
# Epoch 21: val_loss improved from 1.38762 to 0.59659, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 2s - loss: 0.0014 - val_loss: 0.5966 - lr: 0.1000 - 2s/epoch - 309ms/step
# Epoch 22/64
#
# Epoch 22: val_loss improved from 0.59659 to 0.18820, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 6.0460e-04 - val_loss: 0.1882 - lr: 0.1000 - 1s/epoch - 256ms/step
# Epoch 23/64
#
# Epoch 23: val_loss improved from 0.18820 to 0.10816, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.5087e-04 - val_loss: 0.1082 - lr: 0.1000 - 1s/epoch - 250ms/step
# Epoch 24/64
#
# Epoch 24: val_loss did not improve from 0.10816
# 5/5 - 1s - loss: 3.9008e-04 - val_loss: 0.1387 - lr: 0.1000 - 981ms/epoch - 196ms/step
# Epoch 25/64
#
# Epoch 25: val_loss improved from 0.10816 to 0.09481, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 2.4277e-04 - val_loss: 0.0948 - lr: 0.1000 - 1s/epoch - 249ms/step
# Epoch 26/64
#
# Epoch 26: val_loss improved from 0.09481 to 0.05339, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 2.2945e-04 - val_loss: 0.0534 - lr: 0.1000 - 1s/epoch - 287ms/step
# Epoch 27/64
#
# Epoch 27: val_loss improved from 0.05339 to 0.04295, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.9267e-04 - val_loss: 0.0429 - lr: 0.1000 - 1s/epoch - 260ms/step
# Epoch 28/64
#
# Epoch 28: val_loss improved from 0.04295 to 0.03496, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.5820e-04 - val_loss: 0.0350 - lr: 0.1000 - 1s/epoch - 251ms/step
# Epoch 29/64
#
# Epoch 29: val_loss improved from 0.03496 to 0.02800, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.4886e-04 - val_loss: 0.0280 - lr: 0.1000 - 1s/epoch - 259ms/step
# Epoch 30/64
#
# Epoch 30: val_loss improved from 0.02800 to 0.02498, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.4064e-04 - val_loss: 0.0250 - lr: 0.1000 - 1s/epoch - 257ms/step
# Epoch 31/64
#
# Epoch 31: val_loss improved from 0.02498 to 0.01883, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.3033e-04 - val_loss: 0.0188 - lr: 0.1000 - 1s/epoch - 252ms/step
# Epoch 32/64
#
# Epoch 32: val_loss improved from 0.01883 to 0.01541, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.2398e-04 - val_loss: 0.0154 - lr: 0.1000 - 1s/epoch - 249ms/step
# Epoch 33/64
#
# Epoch 33: val_loss improved from 0.01541 to 0.01360, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.2017e-04 - val_loss: 0.0136 - lr: 0.1000 - 1s/epoch - 247ms/step
# Epoch 34/64
#
# Epoch 34: val_loss improved from 0.01360 to 0.01169, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.1579e-04 - val_loss: 0.0117 - lr: 0.1000 - 1s/epoch - 260ms/step
# Epoch 35/64
#
# Epoch 35: val_loss improved from 0.01169 to 0.00948, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.1154e-04 - val_loss: 0.0095 - lr: 0.1000 - 1s/epoch - 254ms/step
# Epoch 36/64
#
# Epoch 36: val_loss improved from 0.00948 to 0.00834, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.0819e-04 - val_loss: 0.0083 - lr: 0.1000 - 1s/epoch - 258ms/step
# Epoch 37/64
#
# Epoch 37: val_loss improved from 0.00834 to 0.00731, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.0515e-04 - val_loss: 0.0073 - lr: 0.1000 - 1s/epoch - 243ms/step
# Epoch 38/64
#
# Epoch 38: val_loss improved from 0.00731 to 0.00618, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.0191e-04 - val_loss: 0.0062 - lr: 0.1000 - 1s/epoch - 238ms/step
# Epoch 39/64
#
# Epoch 39: val_loss improved from 0.00618 to 0.00548, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 9.9026e-05 - val_loss: 0.0055 - lr: 0.1000 - 1s/epoch - 249ms/step
# Epoch 40/64
#
# Epoch 40: val_loss improved from 0.00548 to 0.00482, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 9.6318e-05 - val_loss: 0.0048 - lr: 0.1000 - 1s/epoch - 253ms/step
# Epoch 41/64
#
# Epoch 41: val_loss improved from 0.00482 to 0.00420, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 9.3553e-05 - val_loss: 0.0042 - lr: 0.1000 - 1s/epoch - 261ms/step
# Epoch 42/64
#
# Epoch 42: val_loss improved from 0.00420 to 0.00376, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 9.1089e-05 - val_loss: 0.0038 - lr: 0.1000 - 1s/epoch - 258ms/step
# Epoch 43/64
#
# Epoch 43: val_loss improved from 0.00376 to 0.00331, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 8.8566e-05 - val_loss: 0.0033 - lr: 0.1000 - 1s/epoch - 265ms/step
# Epoch 44/64
#
# Epoch 44: val_loss improved from 0.00331 to 0.00296, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 8.6225e-05 - val_loss: 0.0030 - lr: 0.1000 - 1s/epoch - 247ms/step
# Epoch 45/64
#
# Epoch 45: val_loss improved from 0.00296 to 0.00263, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 8.3951e-05 - val_loss: 0.0026 - lr: 0.1000 - 1s/epoch - 265ms/step
# Epoch 46/64
#
# Epoch 46: val_loss improved from 0.00263 to 0.00236, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 8.1747e-05 - val_loss: 0.0024 - lr: 0.1000 - 1s/epoch - 258ms/step
# Epoch 47/64
#
# Epoch 47: val_loss improved from 0.00236 to 0.00211, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 7.9667e-05 - val_loss: 0.0021 - lr: 0.1000 - 1s/epoch - 262ms/step
# Epoch 48/64
#
# Epoch 48: val_loss improved from 0.00211 to 0.00189, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 7.7601e-05 - val_loss: 0.0019 - lr: 0.1000 - 1s/epoch - 247ms/step
# Epoch 49/64
#
# Epoch 49: val_loss improved from 0.00189 to 0.00171, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 7.5694e-05 - val_loss: 0.0017 - lr: 0.1000 - 1s/epoch - 251ms/step
# Epoch 50/64
#
# Epoch 50: val_loss improved from 0.00171 to 0.00154, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 7.3746e-05 - val_loss: 0.0015 - lr: 0.1000 - 1s/epoch - 253ms/step
# Epoch 51/64
#
# Epoch 51: val_loss improved from 0.00154 to 0.00139, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 7.2027e-05 - val_loss: 0.0014 - lr: 0.1000 - 1s/epoch - 275ms/step
# Epoch 52/64
#
# Epoch 52: val_loss improved from 0.00139 to 0.00127, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 7.0144e-05 - val_loss: 0.0013 - lr: 0.1000 - 1s/epoch - 250ms/step
# Epoch 53/64
#
# Epoch 53: val_loss improved from 0.00127 to 0.00113, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 6.8667e-05 - val_loss: 0.0011 - lr: 0.1000 - 1s/epoch - 253ms/step
# Epoch 54/64
#
# Epoch 54: val_loss improved from 0.00113 to 0.00107, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 6.6770e-05 - val_loss: 0.0011 - lr: 0.1000 - 1s/epoch - 261ms/step
# Epoch 55/64
#
# Epoch 55: val_loss improved from 0.00107 to 0.00090, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 6.5669e-05 - val_loss: 8.9879e-04 - lr: 0.1000 - 1s/epoch - 247ms/step
# Epoch 56/64
#
# Epoch 56: val_loss did not improve from 0.00090
# 5/5 - 1s - loss: 6.3671e-05 - val_loss: 9.2355e-04 - lr: 0.1000 - 965ms/epoch - 193ms/step
# Epoch 57/64
#
# Epoch 57: val_loss improved from 0.00090 to 0.00070, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 6.3106e-05 - val_loss: 7.0023e-04 - lr: 0.1000 - 1s/epoch - 241ms/step
# Epoch 58/64
#
# Epoch 58: val_loss did not improve from 0.00070
# 5/5 - 1s - loss: 6.0984e-05 - val_loss: 8.4031e-04 - lr: 0.1000 - 981ms/epoch - 196ms/step
# Epoch 59/64
#
# Epoch 59: val_loss improved from 0.00070 to 0.00054, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 6.0827e-05 - val_loss: 5.4455e-04 - lr: 0.1000 - 1s/epoch - 270ms/step
# Epoch 60/64
#
# Epoch 60: val_loss did not improve from 0.00054
# 5/5 - 1s - loss: 5.8728e-05 - val_loss: 7.6103e-04 - lr: 0.1000 - 1s/epoch - 207ms/step
# Epoch 61/64
#
# Epoch 61: val_loss improved from 0.00054 to 0.00045, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.7975e-05 - val_loss: 4.4640e-04 - lr: 0.1000 - 1s/epoch - 269ms/step
# Epoch 62/64
#
# Epoch 62: val_loss did not improve from 0.00045
# 5/5 - 1s - loss: 5.6544e-05 - val_loss: 5.7940e-04 - lr: 0.1000 - 995ms/epoch - 199ms/step
# Epoch 63/64
#
# Epoch 63: val_loss improved from 0.00045 to 0.00041, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.4545e-05 - val_loss: 4.0654e-04 - lr: 0.1000 - 1s/epoch - 253ms/step
# Epoch 64/64
#
# Epoch 64: val_loss improved from 0.00041 to 0.00038, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.4381e-05 - val_loss: 3.8493e-04 - lr: 0.1000 - 1s/epoch - 274ms/step

# %% [markdown]
# The results from Experiment 3 were exactly as expected.
#
# Experiment 4) Now, let's apply the same na problem, but this time, variable in time and space. Certain (t, x, y)s are not available, and we want to neither train nor validate on them. We want to test whether sample_weights is able to determine those.

# %%
import random
random.seed(1)
random_data = np.random.rand(n_samples, x, y, n_channels - 2)

channel1_data = np.ones((n_samples, x, y))
channel2_data = np.ones((n_samples, x, y)) * 2

train_x = np.concatenate((channel1_data[:, :, :, np.newaxis],
                          channel2_data[:, :, :, np.newaxis],
                          random_data), axis=-1)

train_y = np.full((n_samples, x, y, 1), 10, dtype=np.float32)

train_y[5, 10:30, 25:150, 0] = -999.
train_y[1, 0:30, 50:180, 0] = -999.
train_y[:, 50:60, :, 0] = -999.

val_x = train_x*1
val_y = train_y*1

train_m = np.ones((n_samples, x, y, 1), dtype=np.float32)
train_m[train_y == -999.] = 0
val_m = np.ones((n_samples, x, y, 1), dtype=np.float32)
val_m[val_y == -999.] = 0

training_unique_name="experiment_sample_weight"
model = Func_Train.UNET(xpixels, ypixels, n_channels, Filters)

# Define optimizer and compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=LR, name='Adam')
#model.compile(optimizer=optimizer, loss=loss, weighted_metrics=['mse'], sample_weight_mode='temporal')
model.compile(optimizer=optimizer, loss=loss, weighted_metrics=[])

# Define the model checkpoint and early stopping callbacks
model_path = PSCRATCH_DIR + '/HPT/' + training_unique_name + '.h5'
checkpointer = tf.keras.callbacks.ModelCheckpoint(model_path, verbose=2, save_best_only=True, monitor='val_loss')
callbacks = [tf.keras.callbacks.EarlyStopping(patience=patience, monitor='val_loss'),
             tf.keras.callbacks.TensorBoard(log_dir=PSCRATCH_DIR + '/HPT/' + training_unique_name)]

# Define the ReduceLROnPlateau callback
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=lr_factor, patience=lr_patience, min_lr=min_LR)

print("Training the model...")

# Train the model using train_x, train_y, train_m and val_x, val_y, val_m
results = model.fit(train_x, train_y, validation_data=(val_x, val_y, val_m),
                    batch_size=BS, epochs=epochs, verbose=2,
                    callbacks=[callbacks, checkpointer, reduce_lr], sample_weight=train_m,
                    shuffle=False)
# Out:
# Training the model...
# Epoch 1/64
#
# Epoch 1: val_loss improved from inf to 220793950320489136128.00000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 7s - loss: 77.2956 - val_loss: 220793950320489136128.0000 - lr: 0.1000 - 7s/epoch - 1s/step
# Epoch 2/64
#
# Epoch 2: val_loss improved from 220793950320489136128.00000 to 824738544877568.00000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 18.2377 - val_loss: 824738544877568.0000 - lr: 0.1000 - 1s/epoch - 255ms/step
# Epoch 3/64
#
# Epoch 3: val_loss improved from 824738544877568.00000 to 1538992111616.00000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 13.2547 - val_loss: 1538992111616.0000 - lr: 0.1000 - 1s/epoch - 274ms/step
# Epoch 4/64
#
# Epoch 4: val_loss improved from 1538992111616.00000 to 7288320000.00000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 2.0932 - val_loss: 7288320000.0000 - lr: 0.1000 - 1s/epoch - 246ms/step
# Epoch 5/64
#
# Epoch 5: val_loss improved from 7288320000.00000 to 783800960.00000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.8834 - val_loss: 783800960.0000 - lr: 0.1000 - 1s/epoch - 263ms/step
# Epoch 6/64
#
# Epoch 6: val_loss improved from 783800960.00000 to 129970968.00000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.4038 - val_loss: 129970968.0000 - lr: 0.1000 - 1s/epoch - 264ms/step
# Epoch 7/64
#
# Epoch 7: val_loss improved from 129970968.00000 to 14123971.00000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.4777 - val_loss: 14123971.0000 - lr: 0.1000 - 1s/epoch - 266ms/step
# Epoch 8/64
#
# Epoch 8: val_loss improved from 14123971.00000 to 984103.50000, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.3609 - val_loss: 984103.5000 - lr: 0.1000 - 1s/epoch - 262ms/step
# Epoch 9/64
#
# Epoch 9: val_loss improved from 984103.50000 to 118084.62500, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.6033 - val_loss: 118084.6250 - lr: 0.1000 - 1s/epoch - 300ms/step
# Epoch 10/64
#
# Epoch 10: val_loss improved from 118084.62500 to 19314.33398, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.1235 - val_loss: 19314.3340 - lr: 0.1000 - 1s/epoch - 276ms/step
# Epoch 11/64
#
# Epoch 11: val_loss improved from 19314.33398 to 4689.91309, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.2237 - val_loss: 4689.9131 - lr: 0.1000 - 1s/epoch - 250ms/step
# Epoch 12/64
#
# Epoch 12: val_loss improved from 4689.91309 to 2988.98169, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0360 - val_loss: 2988.9817 - lr: 0.1000 - 1s/epoch - 243ms/step
# Epoch 13/64
#
# Epoch 13: val_loss improved from 2988.98169 to 346.90338, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0827 - val_loss: 346.9034 - lr: 0.1000 - 1s/epoch - 246ms/step
# Epoch 14/64
#
# Epoch 14: val_loss improved from 346.90338 to 239.58777, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0172 - val_loss: 239.5878 - lr: 0.1000 - 1s/epoch - 248ms/step
# Epoch 15/64
#
# Epoch 15: val_loss improved from 239.58777 to 146.29495, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0238 - val_loss: 146.2950 - lr: 0.1000 - 1s/epoch - 247ms/step
# Epoch 16/64
#
# Epoch 16: val_loss improved from 146.29495 to 51.34343, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0120 - val_loss: 51.3434 - lr: 0.1000 - 1s/epoch - 250ms/step
# Epoch 17/64
#
# Epoch 17: val_loss did not improve from 51.34343
# 5/5 - 1s - loss: 0.0049 - val_loss: 63.3842 - lr: 0.1000 - 967ms/epoch - 193ms/step
# Epoch 18/64
#
# Epoch 18: val_loss improved from 51.34343 to 19.39492, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0062 - val_loss: 19.3949 - lr: 0.1000 - 1s/epoch - 253ms/step
# Epoch 19/64
#
# Epoch 19: val_loss did not improve from 19.39492
# 5/5 - 1s - loss: 0.0015 - val_loss: 29.2137 - lr: 0.1000 - 1s/epoch - 211ms/step
# Epoch 20/64
#
# Epoch 20: val_loss improved from 19.39492 to 12.92615, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0019 - val_loss: 12.9261 - lr: 0.1000 - 1s/epoch - 258ms/step
# Epoch 21/64
#
# Epoch 21: val_loss improved from 12.92615 to 11.49502, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 0.0012 - val_loss: 11.4950 - lr: 0.1000 - 1s/epoch - 248ms/step
# Epoch 22/64
#
# Epoch 22: val_loss improved from 11.49502 to 9.30768, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 3.9493e-04 - val_loss: 9.3077 - lr: 0.1000 - 1s/epoch - 255ms/step
# Epoch 23/64
#
# Epoch 23: val_loss improved from 9.30768 to 6.14098, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.2972e-04 - val_loss: 6.1410 - lr: 0.1000 - 1s/epoch - 267ms/step
# Epoch 24/64
#
# Epoch 24: val_loss improved from 6.14098 to 5.57641, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 2.8999e-04 - val_loss: 5.5764 - lr: 0.1000 - 1s/epoch - 250ms/step
# Epoch 25/64
#
# Epoch 25: val_loss improved from 5.57641 to 3.95814, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.6342e-04 - val_loss: 3.9581 - lr: 0.1000 - 1s/epoch - 252ms/step
# Epoch 26/64
#
# Epoch 26: val_loss improved from 3.95814 to 3.49508, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.8145e-04 - val_loss: 3.4951 - lr: 0.1000 - 1s/epoch - 255ms/step
# Epoch 27/64
#
# Epoch 27: val_loss improved from 3.49508 to 2.58989, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 1.2873e-04 - val_loss: 2.5899 - lr: 0.1000 - 1s/epoch - 262ms/step
# Epoch 28/64
#
# Epoch 28: val_loss improved from 2.58989 to 2.32726, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 9.8913e-05 - val_loss: 2.3273 - lr: 0.1000 - 1s/epoch - 253ms/step
# Epoch 29/64
#
# Epoch 29: val_loss improved from 2.32726 to 1.77640, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 9.9469e-05 - val_loss: 1.7764 - lr: 0.1000 - 1s/epoch - 263ms/step
# Epoch 30/64
#
# Epoch 30: val_loss improved from 1.77640 to 1.57789, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 8.9069e-05 - val_loss: 1.5779 - lr: 0.1000 - 1s/epoch - 247ms/step
# Epoch 31/64
#
# Epoch 31: val_loss improved from 1.57789 to 1.27325, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 7.9504e-05 - val_loss: 1.2732 - lr: 0.1000 - 1s/epoch - 241ms/step
# Epoch 32/64
#
# Epoch 32: val_loss improved from 1.27325 to 1.10687, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 7.6868e-05 - val_loss: 1.1069 - lr: 0.1000 - 1s/epoch - 247ms/step
# Epoch 33/64
#
# Epoch 33: val_loss improved from 1.10687 to 0.93029, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 7.4047e-05 - val_loss: 0.9303 - lr: 0.1000 - 1s/epoch - 274ms/step
# Epoch 34/64
#
# Epoch 34: val_loss improved from 0.93029 to 0.80861, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 7.0452e-05 - val_loss: 0.8086 - lr: 0.1000 - 1s/epoch - 251ms/step
# Epoch 35/64
#
# Epoch 35: val_loss improved from 0.80861 to 0.68938, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 6.7951e-05 - val_loss: 0.6894 - lr: 0.1000 - 1s/epoch - 264ms/step
# Epoch 36/64
#
# Epoch 36: val_loss improved from 0.68938 to 0.60544, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 6.6015e-05 - val_loss: 0.6054 - lr: 0.1000 - 1s/epoch - 281ms/step
# Epoch 37/64
#
# Epoch 37: val_loss improved from 0.60544 to 0.52245, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 6.4010e-05 - val_loss: 0.5224 - lr: 0.1000 - 1s/epoch - 241ms/step
# Epoch 38/64
#
# Epoch 38: val_loss improved from 0.52245 to 0.46168, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 6.2081e-05 - val_loss: 0.4617 - lr: 0.1000 - 1s/epoch - 251ms/step
# Epoch 39/64
#
# Epoch 39: val_loss improved from 0.46168 to 0.40455, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 6.0379e-05 - val_loss: 0.4045 - lr: 0.1000 - 1s/epoch - 250ms/step
# Epoch 40/64
#
# Epoch 40: val_loss improved from 0.40455 to 0.35776, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 2s - loss: 5.8787e-05 - val_loss: 0.3578 - lr: 0.1000 - 2s/epoch - 311ms/step
# Epoch 41/64
#
# Epoch 41: val_loss improved from 0.35776 to 0.31728, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 2s - loss: 5.7241e-05 - val_loss: 0.3173 - lr: 0.1000 - 2s/epoch - 307ms/step
# Epoch 42/64
#
# Epoch 42: val_loss improved from 0.31728 to 0.28196, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.5777e-05 - val_loss: 0.2820 - lr: 0.1000 - 1s/epoch - 252ms/step
# Epoch 43/64
#
# Epoch 43: val_loss improved from 0.28196 to 0.25167, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.4388e-05 - val_loss: 0.2517 - lr: 0.1000 - 1s/epoch - 253ms/step
# Epoch 44/64
#
# Epoch 44: val_loss improved from 0.25167 to 0.22514, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.3058e-05 - val_loss: 0.2251 - lr: 0.1000 - 1s/epoch - 271ms/step
# Epoch 45/64
#
# Epoch 45: val_loss improved from 0.22514 to 0.20187, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.1792e-05 - val_loss: 0.2019 - lr: 0.1000 - 1s/epoch - 251ms/step
# Epoch 46/64
#
# Epoch 46: val_loss improved from 0.20187 to 0.18156, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 5.0578e-05 - val_loss: 0.1816 - lr: 0.1000 - 1s/epoch - 259ms/step
# Epoch 47/64
#
# Epoch 47: val_loss improved from 0.18156 to 0.16358, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.9414e-05 - val_loss: 0.1636 - lr: 0.1000 - 1s/epoch - 246ms/step
# Epoch 48/64
#
# Epoch 48: val_loss improved from 0.16358 to 0.14766, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.8302e-05 - val_loss: 0.1477 - lr: 0.1000 - 1s/epoch - 258ms/step
# Epoch 49/64
#
# Epoch 49: val_loss improved from 0.14766 to 0.13363, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.7232e-05 - val_loss: 0.1336 - lr: 0.1000 - 1s/epoch - 256ms/step
# Epoch 50/64
#
# Epoch 50: val_loss improved from 0.13363 to 0.12103, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.6208e-05 - val_loss: 0.1210 - lr: 0.1000 - 1s/epoch - 264ms/step
# Epoch 51/64
#
# Epoch 51: val_loss improved from 0.12103 to 0.10989, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.5226e-05 - val_loss: 0.1099 - lr: 0.1000 - 1s/epoch - 244ms/step
# Epoch 52/64
#
# Epoch 52: val_loss improved from 0.10989 to 0.09986, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.4278e-05 - val_loss: 0.0999 - lr: 0.1000 - 1s/epoch - 252ms/step
# Epoch 53/64
#
# Epoch 53: val_loss improved from 0.09986 to 0.09089, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.3372e-05 - val_loss: 0.0909 - lr: 0.1000 - 1s/epoch - 263ms/step
# Epoch 54/64
#
# Epoch 54: val_loss improved from 0.09089 to 0.08285, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.2496e-05 - val_loss: 0.0828 - lr: 0.1000 - 1s/epoch - 246ms/step
# Epoch 55/64
#
# Epoch 55: val_loss improved from 0.08285 to 0.07557, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.1656e-05 - val_loss: 0.0756 - lr: 0.1000 - 1s/epoch - 264ms/step
# Epoch 56/64
#
# Epoch 56: val_loss improved from 0.07557 to 0.06903, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.0845e-05 - val_loss: 0.0690 - lr: 0.1000 - 1s/epoch - 250ms/step
# Epoch 57/64
#
# Epoch 57: val_loss improved from 0.06903 to 0.06311, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 4.0064e-05 - val_loss: 0.0631 - lr: 0.1000 - 1s/epoch - 267ms/step
# Epoch 58/64
#
# Epoch 58: val_loss improved from 0.06311 to 0.05774, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 3.9312e-05 - val_loss: 0.0577 - lr: 0.1000 - 1s/epoch - 253ms/step
# Epoch 59/64
#
# Epoch 59: val_loss improved from 0.05774 to 0.05288, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 3.8586e-05 - val_loss: 0.0529 - lr: 0.1000 - 1s/epoch - 243ms/step
# Epoch 60/64
#
# Epoch 60: val_loss improved from 0.05288 to 0.04846, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 3.7886e-05 - val_loss: 0.0485 - lr: 0.1000 - 1s/epoch - 248ms/step
# Epoch 61/64
#
# Epoch 61: val_loss improved from 0.04846 to 0.04444, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 3.7210e-05 - val_loss: 0.0444 - lr: 0.1000 - 1s/epoch - 245ms/step
# Epoch 62/64
#
# Epoch 62: val_loss improved from 0.04444 to 0.04077, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 3.6558e-05 - val_loss: 0.0408 - lr: 0.1000 - 1s/epoch - 256ms/step
# Epoch 63/64
#
# Epoch 63: val_loss improved from 0.04077 to 0.03744, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 3.5927e-05 - val_loss: 0.0374 - lr: 0.1000 - 1s/epoch - 295ms/step
# Epoch 64/64
#
# Epoch 64: val_loss improved from 0.03744 to 0.03438, saving model to /p/scratch/deepacf/kiste/patakchiyousefi1//HPT/experiment_sample_weight.h5
# 5/5 - 1s - loss: 3.5319e-05 - val_loss: 0.0344 - lr: 0.1000 - 1s/epoch - 245ms/step

# %% [markdown]
# So far, so good.
#
# Experiment 5) Now, let's add a 'mse' metric and see whether it incorporates weights in the calculations of training and validation mse

# %%
import random
random.seed(1)
random_data = np.random.rand(n_samples, x, y, n_channels - 2)

channel1_data = np.ones((n_samples, x, y))
channel2_data = np.ones((n_samples, x, y)) * 2

train_x = np.concatenate((channel1_data[:, :, :, np.newaxis],
                          channel2_data[:, :, :, np.newaxis],
                          random_data), axis=-1)

train_y = np.full((n_samples, x, y, 1), 10, dtype=np.float32)

train_y[5, 10:30, 25:150, 0] = -999.
train_y[1, 0:30, 50:180, 0] = -999.
train_y[:, 50:60, :, 0] = -999.

val_x = train_x*1
val_y = train_y*1

train_m = np.ones((n_samples, x, y, 1), dtype=np.float32)
train_m[train_y == -999.] = 0
val_m = np.ones((n_samples, x, y, 1), dtype=np.float32)
val_m[val_y == -999.] = 0

training_unique_name="experiment_sample_weight"
model = Func_Train.UNET(xpixels, ypixels, n_channels, Filters)

# Define optimizer and compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=LR, name='Adam')
model.compile(optimizer=optimizer, loss=loss, weighted_metrics=['mse'])
#model.compile(optimizer=optimizer, loss=loss, weighted_metrics=[], , sample_weight_mode='temporal)

# Define the model checkpoint and early stopping callbacks
model_path = PSCRATCH_DIR + '/HPT/' + training_unique_name + '.h5'
checkpointer = tf.keras.callbacks.ModelCheckpoint(model_path, verbose=2, save_best_only=True, monitor='val_loss')
callbacks = [tf.keras.callbacks.EarlyStopping(patience=patience, monitor='val_loss'),
             tf.keras.callbacks.TensorBoard(log_dir=PSCRATCH_DIR + '/HPT/' + training_unique_name)]

# Define the ReduceLROnPlateau callback
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=lr_factor, patience=lr_patience, min_lr=min_LR)

print("Training the model...")

# Train the model using train_x, train_y, train_m and val_x, val_y, val_m
results = model.fit(train_x, train_y, validation_data=(val_x, val_y, val_m),
                    batch_size=BS, epochs=epochs, verbose=2,
                    callbacks=[callbacks, checkpointer, reduce_lr], sample_weight=train_m,
                    shuffle=False)
